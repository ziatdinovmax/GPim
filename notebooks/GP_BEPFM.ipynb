# %% [markdown]
# <a href="https://colab.research.google.com/github/ziatdinovmax/GP/blob/master/notebooks/GP_BEPFM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gaussian Process Regression Applied to Hyperspectral Data from BE-PFM Experiments
#
# Prepared by Maxim Ziatdinov (October 2019)
#
# Email: ziatdinovmax@gmail.com

# %% [markdown]
# This notebook demonstates application of Gaussian process regression to reconstruction of (artificially corrupted) BE-PFM hyperspecral data and to a sample exploration based on uncertainty.

# %% [markdown]
# ---
# **Important:** For the best performance, please run this notebook with the latest generation GPUs, such as Nvidia's Tesla P100 and Tesla V100. You can get those GPUs in a cloud by [connecting](https://blog.kovalevskyi.com/gce-deeplearning-images-as-a-backend-for-google-colaboratory-bc4903d24947) this Colab notebook to a [Deep Learning VM](https://cloud.google.com/deep-learning-vm/) on Google Cloud Platform. It is also possible to run this notebook in Google Colab hosted runtime with (free) Tesla K80 GPU but the computational time will be significantly longer.
#
#
# ---

# %% [markdown]
# Check your cloud GPU:

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 03:54:04 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title Import/install modules { form-width: "20%" }
import os
import copy
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
try:
    import pyro
except:
    ModuleNotFoundError
    print('Installing Pyro library...', end=" ")
    # !pip install pyro-ppl==0.4.1 > /dev/null
    print("Done")
    import pyro
if 'GP' not in os.path.split(os.getcwd()):
    try:
        os.chdir('GP')
    except FileNotFoundError:
        print("Cloning package for GP analysis of hyperspectral data...", end=" ")
        # !git clone -q https://github.com/ziatdinovmax/GP.git
        os.chdir('GP')
        print("Done")
from gprocess import gpr, gprutils
import torch
pyro.set_rng_seed(0)
torch.set_default_tensor_type(torch.DoubleTensor)
# Out:
# Installing Pyro library... Done
# Cloning package for GP analysis of hyperspectral data... Done

# %%
#@title Helper functions { form-width: "20%" }

def print_attrs(name, obj):
    print(name)
    for k, v in obj.attrs.items():
        print("  {}: {}".format(k, v))

def inspect_dataset(hf, **kwargs):
    hf.visititems(print_attrs)
    return

def get_raw_data(hf, measurement='Measurement_000', channel='Channel_000'):
    raw_data = hf[measurement+'/'+channel+'/Raw_Data'][:]
    return raw_data

def get_dims(hf, measurement='Measurement_000'):
    cols = hf[measurement].attrs['grid_num_cols']
    rows = hf[measurement].attrs['grid_num_rows']
    bins = hf[measurement].attrs['num_bins']
    return cols, rows, bins 

def get_spectr_info(hf, measurement='Measurement_000', channel='Channel_000'):
    spec_values = hf[measurement+'/'+channel+'/Spectroscopic_Values'][:]
    spec_units = hf[measurement+'/'+channel+'/Spectroscopic_Indices'].attrs['units']
    spec_label = hf[measurement+'/'+channel+'/Spectroscopic_Indices'].attrs['labels']
    return spec_values, spec_units[0].decode('utf-8'), spec_label[0].decode('utf-8')

# %% [markdown]
# ### Review dataset(s)

# %% [markdown]
# Select a file to work with and print the hdf5 file data tree:

# %%
datadir = 'test_data'
filename = 'BEPFM image_0001 - 128 x 128.h5'

hf = h5py.File(os.path.join(datadir, filename), 'r')
inspect_dataset(hf)
# Out:
# Measurement_000
#   num_bins: 102
#   num_pix: 16384
#   num_steps: 1
#   num_UDVS_bins: 102
#   data_type: b'BELineData'
#   VS_mode: b'none'
#   BE_phase_content: b'chirp-sinc hybrid'
#   AFM_XLVDT_sensor: 4.2214e-06
#   AFM_YLVDT_sensor: 4.3626e-06
#   AFM_ZLVDT_sensor: 4.790395e-06
#   AFM_XPiezo_sensitivity: -1.7437e-07
#   AFM_YPiezo_sensitivity: 1.8489e-07
#   AFM_ZPiezo_sensitivity: 2.95923e-08
#   AFM_InvOLS: 1e-07
#   grid_num_cols: 128
#   grid_num_rows: 128
#   grid__scan_rate_[Hz]: 0.95367431640625
#   grid__set-point_[V]: 1.0
#   IO_AFM_platform: b'Cypher'
#   IO_card: b'6124'
#   IO_rate: 4000000.0
#   IO_AO_range: 10.0
#   IO_AI_range: 10.0
#   IO_analog_output_amplifier_ring: 1.0
#   IO_deflection_detector_ring: 0
#   IO_sensitivity: 1.0
#   IO_Channel_001_type: b'none'
#   IO_Channel_002_type: b'none'
#   IO_Channel_003_type: b'none'
#   BE_signal_type_ring: 1.0
#   BE_band_width_[Hz]: 50000.0
#   BE_center_frequency_[Hz]: 323000.0
#   BE_amplitude_[V]: 2.0
#   BE_phase_variation: 1.0
#   BE_repeats: 1.0
#   BE_auto_smooth_cond: 1.0
#   BE_smoothing: 3208.717049919559
#   BE_window_adjustment: 0.215625
#   BE_pulse_duration_[s]: 0.004
#   grid_current_row: 127
# Measurement_000/Channel_000
#   channel_type: b'BE'
# Measurement_000/Channel_000/Bin_FFT
# Measurement_000/Channel_000/Bin_Frequencies
# Measurement_000/Channel_000/Bin_Indices
# Measurement_000/Channel_000/Bin_Step
# Measurement_000/Channel_000/Bin_Wfm_Type
# Measurement_000/Channel_000/Excitation_Waveform
# Measurement_000/Channel_000/Noise_Floor
# Measurement_000/Channel_000/Position_Indices
#   units: [b'nm' b'nm']
#   labels: [b'X' b'Y']
# Measurement_000/Channel_000/Position_Values
#   units: [b'nm' b'nm']
#   labels: [b'X' b'Y']
# Measurement_000/Channel_000/Raw_Data
#   Position_Indices: 33554433
# Measurement_000/Channel_000/Raw_Data-SHO_Fit_000
#   units: [b'']
# Measurement_000/Channel_000/Raw_Data-SHO_Fit_000/Guess
# Measurement_000/Channel_000/Raw_Data-SHO_Fit_000/Spectroscopic_Indices
#   labels: [b'']
# Measurement_000/Channel_000/Raw_Data-SHO_Fit_000/Spectroscopic_Values
#   labels: [b'']
#   units: [b'']
# Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
#   Name: b'DC Bias'
# Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# Measurement_000/Channel_000/Spectroscopic_Indices
#   units: [b'Hz']
#   labels: [b'Frequency']
# Measurement_000/Channel_000/Spectroscopic_Values
#   units: [b'Hz']
#   labels: [b'Frequency']
# Measurement_000/Channel_000/UDVS
# Measurement_000/Channel_000/UDVS_Indices

# %% [markdown]
# Get the raw data and reshape it:

# %%
raw_data = get_raw_data(hf, measurement='Measurement_000', channel='Channel_000')
print('data dimensions: {}'.format(raw_data.shape))
raw_data = raw_data.reshape(get_dims(hf, measurement='Measurement_000'))
raw_data = np.abs(raw_data).astype(np.float64)
print('reshaped data dimensions: {}'.format(raw_data.shape))
#hf.close()
# Out:
# data dimensions: (16384, 102)
# reshaped data dimensions: (128, 128, 102)

# %% [markdown]
# Plot selected slices of hyperspectral cube and individual spectroscopic curves:

# %%
# choose slice
slice_number = 57
spectral_window = 10
# select cooordinates for individual spectroscopic curves
pos = [
       [10, 20], 
       [25, 22], 
       [29, 27],
]
# Plotting
gprutils.plot_raw_data(raw_data, slice_number, pos, spectral_window)

# %% [markdown]
# ## Prepare data

# %% [markdown]
# Take part of data (for testing purposes):

# %%
# define crop size
x_start, x_end = 0, 32
y_start, y_end = 0, 32
z_start, z_end = 0, 102
x_res, y_res, z_res = 1, 1, 1
# adjust manually if necessary
pos = [
       [10, 20], 
       [24, 22], 
       [29, 27],
]
# crop and plot
R_true = raw_data[x_start:x_end:x_res, y_start:y_end:y_res, z_start:z_end:z_res]
R_true = (R_true - np.amin(R_true))/np.ptp(R_true)
gprutils.plot_raw_data(R_true, slice_number, pos, spectral_window)

# %% [markdown]
# Now we corrupt data by removing certain percentage of the observations:

# %%
remove_obs = 0.7 # remove 70 % of the data

# Store "true" grid indices before removing parts of the data
e1, e2, e3 = R_true.shape
c1, c2, c3 = np.mgrid[:e1:1., :e2:1., :e3:1.]
X_true = np.array([c1, c2, c3])
# Remove observations and plot the new "corrupted" data
X, R = gprutils.corrupt_data_xy(X_true, R_true, prob=remove_obs)
gprutils.plot_raw_data(R, slice_number, pos, spectral_window, norm=True)

# %% [markdown]
# ## Gaussian Process Regression Analysis

# %% [markdown]
# We now run GP regression on the corrupted data to reconstruct the original signal:

# %%
#@title GP regression: model training and prediction (select parameters and click 'Run') { form-width: "50%" }
KERNEL = "Matern52" #@param ["RationalQuadratic", "RBF", "Matern52"]
LENGTH_CONSTR_MIN = 1 #@param {type:"slider", min:1, max:100, step:0.5}
LENGTH_CONSTR_MAX = 20 #@param {type:"slider", min:5, max:100, step:0.5}
LEARNING_RATE = 0.1 #@param {type:"slider", min:0.0005, max:0.1, step:0.0005}
STEPS = 1000 #@param {type:"slider", min:100, max:10000, step:100}
INDUCING_POINTS = 1500 #@param {type:"slider", min:20, max:10000, step:10}
USE_GPU = True #@param ["True", "False"] {type:"raw"}

LENGTH_CONSTR = [
                 [float(LENGTH_CONSTR_MIN) for i in range(3)],
                 [float(LENGTH_CONSTR_MAX) for i in range(3)]
]

reconstr = gpr.reconstructor(
    X, R, X_true, KERNEL, LENGTH_CONSTR, INDUCING_POINTS, 3,
    LEARNING_RATE, STEPS, num_batches=100, use_gpu=USE_GPU, verbose=True
)
mean, sd, hyperparams = reconstr.run()
# Out:
# # of inducing points for GP regression: 1536
# Model training...
# iter: 0 ... loss: 43357.9821 ... amp: 1.0 ... length: [1. 1. 1.] ... noise: 1.0 ...
# iter: 100 ... loss: -54096.0379 ... amp: 0.0049 ... length: [ 3.7321  5.6455 13.5962] ... noise: 0.0014048 ...
# average time per iteration: 0.3691 s
# iter: 200 ... loss: -67768.7915 ... amp: 0.0072 ... length: [ 2.5511  3.85   16.5067] ... noise: 0.0003573 ...
# iter: 300 ... loss: -68075.9201 ... amp: 0.0078 ... length: [ 2.5913  3.8913 16.8184] ... noise: 0.0003494 ...
# iter: 400 ... loss: -68236.043 ... amp: 0.0082 ... length: [ 2.6265  3.9277 17.0209] ... noise: 0.0003448 ...
# iter: 500 ... loss: -68297.3374 ... amp: 0.0084 ... length: [ 2.6341  3.9668 17.1632] ... noise: 0.0003439 ...
# iter: 600 ... loss: -68325.7212 ... amp: 0.0085 ... length: [ 2.639   3.9854 17.2196] ... noise: 0.000343 ...
# iter: 700 ... loss: -68341.5756 ... amp: 0.0086 ... length: [ 2.6489  3.9926 17.2653] ... noise: 0.0003427 ...
# iter: 800 ... loss: -68354.6841 ... amp: 0.0087 ... length: [ 2.651   3.9921 17.2858] ... noise: 0.0003424 ...
# iter: 900 ... loss: -68357.1104 ... amp: 0.0087 ... length: [ 2.6536  3.9919 17.2852] ... noise: 0.0003421 ...
# iter: 999 ... loss: -68366.7451 ... amp: 0.0087 ... length: [ 2.6551  3.9923 17.2947] ... noise: 0.0003418 ...
# training completed in 368.81 s
# Final parameter values:
#  amp: 0.0087, lengthscale: [ 2.6551  3.9923 17.2947], noise: 0.0003418
# Calculating predictive mean and variance... Done

# %% [markdown]
# Plot the evolution of hyperparameters during the training:

# %%
gprutils.plot_kernel_hyperparams(hyperparams)

# %% [markdown]
# Plot the evolution of inducing points:
#
# (may take up to ~1 minute)

# %%
gprutils.plot_inducing_points(hyperparams, slice_step=2)

# %% [markdown]
# Plot the results:

# %%
gprutils.plot_reconstructed_data3d(R, mean, sd, slice_number, pos, spectral_window)

# %% [markdown]
# ## Sample exploration with GP regression

# %% [markdown]
# We are now going to expore our "sample" in the iterative fashion:
# Use GPR to reconstruct data from initial "observations" --> do "measurement" in the point with maximum uncertainty (as estimated from GPR) --> Add the new "measured" points to the initial points --> repeat.

# %% [markdown]
# Prepare data:

# %%
# define crop size
x_start, x_end = 0, 32
y_start, y_end = 0, 32
z_start, z_end = 0, 102
x_res, y_res, z_res = 1, 1, 1
# get the subset of data
R_true = raw_data[x_start:x_end:x_res, y_start:y_end:y_res, z_start:z_end:z_res]
R_true = (R_true - np.amin(R_true))/np.ptp(R_true)
e1, e2, e3 = R_true.shape
c1, c2, c3 = np.mgrid[:e1:1., :e2:1., :e3:1.]
X_true = np.array([c1, c2, c3])
# Let's start with "measuring" several points along each edge
R = R_true*0
R[R==0] = np.nan
R = gprutils.open_edge_points(R, R_true)
X, R = gprutils.corrupt_data_xy(X_true, R)

# %% [markdown]
# Run the analysis. We are going to increase a learning rate while decreasing a number of SVI steps in each iteration to see how fast we can discover new things in the "sample".
#
# (notice that the size of a measurement square is defined as 2*M+1, so that M=0 corresponds to a doing a single measurement)

# %%
#@title GP exploration (select parameters and click 'Run') { form-width: "40%" }
EXPLORATION_STEPS = 100 #@param {type:"slider", min:1, max:300, step:1}
MEASUREMENT_AREA = 0 #@param {type:"slider", min:0, max:5, step:1}
KERNEL = "Matern52" #@param ["RationalQuadratic", "RBF", "Matern52"]
LENGTH_CONSTR_MIN = 1 #@param {type:"slider", min:1, max:100, step:0.5}
LENGTH_CONSTR_MAX = 20 #@param {type:"slider", min:5, max:100, step:0.5}
LEARNING_RATE = 0.1 #@param {type:"slider", min:0.0005, max:0.1, step:0.0005}
STEPS = 500 #@param {type:"slider", min:100, max:10000, step:100}
DISTANCE_EDGE = 0 #@param {type:"slider", min:0, max:10, step:1}
USE_GPU = True #@param ["True", "False"] {type:"raw"}
SAVE_DIR = "Output" #@param {type:"string"}

LENGTH_CONSTR = [
                 [float(LENGTH_CONSTR_MIN) for i in range(3)],
                 [float(LENGTH_CONSTR_MAX) for i in range(3)]
]
DIST_EDGE = [DISTANCE_EDGE, DISTANCE_EDGE]
MSIZE = MEASUREMENT_AREA

# Run exploratory analysis
uncert_idx_all, uncert_val_all, mean_all, sd_all, R_all = [], [], [], [], []
if not os.path.exists(SAVE_DIR): os.makedirs(SAVE_DIR)
for i in range(EXPLORATION_STEPS):
    print('Exploration step {}/{}'.format(i, EXPLORATION_STEPS))
    # Make the number of inducing points dependent on the number of datapoints
    indpoints = len(gprutils.prepare_training_data(X, R)[0]) // 20
    # Initialize explorer
    bexplorer = gpr.reconstructor(
        X, R, X_true, KERNEL, LENGTH_CONSTR, indpoints, 3,
        LEARNING_RATE, STEPS, num_batches=10, use_gpu=USE_GPU,
        verbose=False)
    # get indices/value of a max uncertainty point
    uncert_idx, uncert_val, mean, sd = bexplorer.step(DIST_EDGE)
    # some safeguards (to not stuck at one point)
    uncert_idx, uncert_val = gprutils.checkvalues(
        uncert_idx, uncert_idx_all, uncert_val)
    # store intermediate results 
    uncert_idx_all.append(uncert_idx)
    uncert_val_all.append(uncert_val)
    R_all.append(copy.deepcopy(R.flatten()))
    mean_all.append(copy.deepcopy(mean))
    sd_all.append(copy.deepcopy(sd))
    # make a "measurement" in the point with maximum uncertainty
    print('Doing "measurement"...\n')
    R, X = gprutils.do_measurement(
        R_true, X_true, R, X, uncert_idx, MSIZE)
    # (over)write results on disk
    np.save(os.path.join(
        SAVE_DIR, 'sgpr_bepfm_R_4.npy'), R_all)
    np.save(os.path.join(
        SAVE_DIR, 'sgpr_bepfm_means_4.npy'), mean_all)
    np.save(os.path.join(
        SAVE_DIR, 'sgpr_bepfm_sd_4.npy'), sd_all)
    np.save(os.path.join(
        SAVE_DIR, 'sgpr_bepfm_amax_4.npy'), uncert_idx_all)
# Out:
# Exploration step 0/100
# # of inducing points for GP regression: 102
# Model training...
# average time per iteration: 0.0147 s
# training completed in 7.28 s
# Final parameter values:
#  amp: 0.0084, lengthscale: [10.6267 10.1159 17.6672], noise: 0.0007307
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 8.427961955114975 at [15, 16]
# Doing "measurement"...
#
# Exploration step 1/100
# # of inducing points for GP regression: 108
# Model training...
# average time per iteration: 0.015700000000000002 s
# training completed in 7.37 s
# Final parameter values:
#  amp: 0.0086, lengthscale: [10.5195 10.2663 17.9558], noise: 0.000755
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 6.217712660406696 at [21, 10]
# Doing "measurement"...
#
# Exploration step 2/100
# # of inducing points for GP regression: 113
# Model training...
# average time per iteration: 0.015700000000000002 s
# training completed in 7.32 s
# Final parameter values:
#  amp: 0.0085, lengthscale: [10.7574 10.4618 17.6464], noise: 0.000734
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 5.898565769325797 at [22, 22]
# Doing "measurement"...
#
# Exploration step 3/100
# # of inducing points for GP regression: 118
# Model training...
# average time per iteration: 0.016 s
# training completed in 7.44 s
# Final parameter values:
#  amp: 0.0083, lengthscale: [10.6584 10.2096 17.7591], noise: 0.000742
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 5.814734570434891 at [9, 9]
# Doing "measurement"...
#
# Exploration step 4/100
# # of inducing points for GP regression: 123
# Model training...
# average time per iteration: 0.0159 s
# training completed in 7.39 s
# Final parameter values:
#  amp: 0.0076, lengthscale: [10.5613 10.0399 17.3726], noise: 0.0007449
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 5.7081653869238185 at [9, 22]
# Doing "measurement"...
#
# Exploration step 5/100
# # of inducing points for GP regression: 128
# Model training...
# average time per iteration: 0.0161 s
# training completed in 7.49 s
# Final parameter values:
#  amp: 0.0079, lengthscale: [10.4554 10.4446 17.6392], noise: 0.0007508
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.5110500127008075 at [15, 25]
# Doing "measurement"...
#
# Exploration step 6/100
# # of inducing points for GP regression: 133
# Model training...
# average time per iteration: 0.0158 s
# training completed in 7.47 s
# Final parameter values:
#  amp: 0.0093, lengthscale: [10.6384 10.551  18.5539], noise: 0.0007476
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.688881204945291 at [6, 16]
# Doing "measurement"...
#
# Exploration step 7/100
# # of inducing points for GP regression: 138
# Model training...
# average time per iteration: 0.0158 s
# training completed in 7.51 s
# Final parameter values:
#  amp: 0.0092, lengthscale: [10.5834 10.7191 18.5559], noise: 0.0007146
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.518265672245677 at [15, 6]
# Doing "measurement"...
#
# Exploration step 8/100
# # of inducing points for GP regression: 143
# Model training...
# average time per iteration: 0.0165 s
# training completed in 7.6 s
# Final parameter values:
#  amp: 0.0095, lengthscale: [10.8943 10.8001 18.6963], noise: 0.0006945
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.407042653483903 at [25, 15]
# Doing "measurement"...
#
# Exploration step 9/100
# # of inducing points for GP regression: 148
# Model training...
# average time per iteration: 0.016399999999999998 s
# training completed in 7.45 s
# Final parameter values:
#  amp: 0.0096, lengthscale: [10.671  10.7015 18.2941], noise: 0.0007173
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.347432013529203 at [25, 6]
# Doing "measurement"...
#
# Exploration step 10/100
# # of inducing points for GP regression: 153
# Model training...
# average time per iteration: 0.0163 s
# training completed in 7.63 s
# Final parameter values:
#  amp: 0.0103, lengthscale: [10.6201 11.2901 18.3916], noise: 0.0006967
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.104630755953186 at [5, 25]
# Doing "measurement"...
#
# Exploration step 11/100
# # of inducing points for GP regression: 159
# Model training...
# average time per iteration: 0.0166 s
# training completed in 7.73 s
# Final parameter values:
#  amp: 0.0105, lengthscale: [10.7995 10.6372 18.4332], noise: 0.0007092
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.200536103012039 at [5, 5]
# Doing "measurement"...
#
# Exploration step 12/100
# # of inducing points for GP regression: 164
# Model training...
# average time per iteration: 0.0167 s
# training completed in 7.78 s
# Final parameter values:
#  amp: 0.0113, lengthscale: [11.1335 10.7929 18.8122], noise: 0.000668
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.0082235665799 at [25, 26]
# Doing "measurement"...
#
# Exploration step 13/100
# # of inducing points for GP regression: 169
# Model training...
# average time per iteration: 0.0165 s
# training completed in 7.78 s
# Final parameter values:
#  amp: 0.0118, lengthscale: [10.9299 11.3642 18.9523], noise: 0.0006449
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.979875073492924 at [21, 17]
# Doing "measurement"...
#
# Exploration step 14/100
# # of inducing points for GP regression: 174
# Model training...
# average time per iteration: 0.0168 s
# training completed in 7.81 s
# Final parameter values:
#  amp: 0.0113, lengthscale: [10.8974 10.7681 18.5673], noise: 0.0006503
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.809421933938525 at [11, 13]
# Doing "measurement"...
#
# Exploration step 15/100
# # of inducing points for GP regression: 179
# Model training...
# average time per iteration: 0.0172 s
# training completed in 8.03 s
# Final parameter values:
#  amp: 0.0108, lengthscale: [10.59   10.3132 18.495 ], noise: 0.0006475
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.834418621656817 at [17, 20]
# Doing "measurement"...
#
# Exploration step 16/100
# # of inducing points for GP regression: 184
# Model training...
# average time per iteration: 0.0172 s
# training completed in 8.1 s
# Final parameter values:
#  amp: 0.0112, lengthscale: [10.1555 10.8502 18.5079], noise: 0.0006379
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7717329205749355 at [17, 11]
# Doing "measurement"...
#
# Exploration step 17/100
# # of inducing points for GP regression: 189
# Model training...
# average time per iteration: 0.0176 s
# training completed in 8.19 s
# Final parameter values:
#  amp: 0.0109, lengthscale: [10.014  10.7966 18.4937], noise: 0.0006073
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.658216811518082 at [27, 20]
# Doing "measurement"...
#
# Exploration step 18/100
# # of inducing points for GP regression: 194
# Model training...
# average time per iteration: 0.0178 s
# training completed in 8.27 s
# Final parameter values:
#  amp: 0.0102, lengthscale: [ 9.7095 10.5602 18.0881], noise: 0.0006148
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6880067090284445 at [4, 12]
# Doing "measurement"...
#
# Exploration step 19/100
# # of inducing points for GP regression: 199
# Model training...
# average time per iteration: 0.0178 s
# training completed in 8.32 s
# Final parameter values:
#  amp: 0.0093, lengthscale: [ 8.5369  9.9308 18.0698], noise: 0.000664
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.882340857653229 at [27, 11]
# Doing "measurement"...
#
# Exploration step 20/100
# # of inducing points for GP regression: 204
# Model training...
# average time per iteration: 0.0175 s
# training completed in 8.33 s
# Final parameter values:
#  amp: 0.0092, lengthscale: [ 8.3886  9.8057 17.8883], noise: 0.0006637
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.9523029181117115 at [20, 5]
# Doing "measurement"...
#
# Exploration step 21/100
# # of inducing points for GP regression: 210
# Model training...
# average time per iteration: 0.0183 s
# training completed in 8.59 s
# Final parameter values:
#  amp: 0.01, lengthscale: [ 8.1101  9.9649 18.4982], noise: 0.0006901
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.03296021397668 at [20, 27]
# Doing "measurement"...
#
# Exploration step 22/100
# # of inducing points for GP regression: 215
# Model training...
# average time per iteration: 0.018000000000000002 s
# training completed in 8.52 s
# Final parameter values:
#  amp: 0.0106, lengthscale: [ 8.2334 10.0429 18.6294], noise: 0.0006859
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.078505444085932 at [11, 27]
# Doing "measurement"...
#
# Exploration step 23/100
# # of inducing points for GP regression: 220
# Model training...
# average time per iteration: 0.0184 s
# training completed in 8.78 s
# Final parameter values:
#  amp: 0.0107, lengthscale: [ 8.4222  9.9829 18.5342], noise: 0.0006723
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.901391399989795 at [11, 5]
# Doing "measurement"...
#
# Exploration step 24/100
# # of inducing points for GP regression: 225
# Model training...
# average time per iteration: 0.018799999999999997 s
# training completed in 8.85 s
# Final parameter values:
#  amp: 0.0094, lengthscale: [ 7.8726  9.5592 18.0645], noise: 0.0006786
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.985005114149393 at [12, 19]
# Doing "measurement"...
#
# Exploration step 25/100
# # of inducing points for GP regression: 230
# Model training...
# average time per iteration: 0.0187 s
# training completed in 8.89 s
# Final parameter values:
#  amp: 0.0096, lengthscale: [ 8.0798  9.4532 18.3022], noise: 0.0006443
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7908722919913473 at [4, 20]
# Doing "measurement"...
#
# Exploration step 26/100
# # of inducing points for GP regression: 235
# Model training...
# average time per iteration: 0.0194 s
# training completed in 9.13 s
# Final parameter values:
#  amp: 0.0102, lengthscale: [ 7.9997  9.9454 18.4349], noise: 0.0006337
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7036100516036488 at [27, 25]
# Doing "measurement"...
#
# Exploration step 27/100
# # of inducing points for GP regression: 240
# Model training...
# average time per iteration: 0.0192 s
# training completed in 9.03 s
# Final parameter values:
#  amp: 0.0099, lengthscale: [ 7.9721  9.7599 18.3754], noise: 0.0006223
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.619981035858015 at [3, 31]
# Doing "measurement"...
#
# Exploration step 28/100
# # of inducing points for GP regression: 245
# Model training...
# average time per iteration: 0.0192 s
# training completed in 9.06 s
# Final parameter values:
#  amp: 0.0099, lengthscale: [ 8.3059  9.3266 18.4355], noise: 0.0005995
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.684628406282433 at [31, 0]
# Doing "measurement"...
#
# Exploration step 29/100
# # of inducing points for GP regression: 250
# Model training...
# average time per iteration: 0.0195 s
# training completed in 9.33 s
# Final parameter values:
#  amp: 0.0107, lengthscale: [ 8.3784  9.5114 18.6536], noise: 0.0005901
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6074286591697677 at [31, 28]
# Doing "measurement"...
#
# Exploration step 30/100
# # of inducing points for GP regression: 255
# Model training...
# average time per iteration: 0.0197 s
# training completed in 9.3 s
# Final parameter values:
#  amp: 0.011, lengthscale: [ 8.3152  9.5853 18.8294], noise: 0.0005722
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.568464737534683 at [27, 3]
# Doing "measurement"...
#
# Exploration step 31/100
# # of inducing points for GP regression: 261
# Model training...
# average time per iteration: 0.021099999999999997 s
# training completed in 9.97 s
# Final parameter values:
#  amp: 0.011, lengthscale: [ 8.3654  9.6049 18.7981], noise: 0.0005546
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.444449582815354 at [3, 0]
# Doing "measurement"...
#
# Exploration step 32/100
# # of inducing points for GP regression: 266
# Model training...
# average time per iteration: 0.021400000000000002 s
# training completed in 10.06 s
# Final parameter values:
#  amp: 0.0118, lengthscale: [ 8.3378  9.8691 18.8085], noise: 0.0005483
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.506904989998918 at [0, 25]
# Doing "measurement"...
#
# Exploration step 33/100
# # of inducing points for GP regression: 271
# Model training...
# average time per iteration: 0.022000000000000002 s
# training completed in 10.3 s
# Final parameter values:
#  amp: 0.0117, lengthscale: [ 8.214   9.9256 18.847 ], noise: 0.0005291
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.435251072164629 at [15, 31]
# Doing "measurement"...
#
# Exploration step 34/100
# # of inducing points for GP regression: 276
# Model training...
# average time per iteration: 0.022099999999999998 s
# training completed in 10.26 s
# Final parameter values:
#  amp: 0.0119, lengthscale: [ 8.2199  9.896  18.9551], noise: 0.0005107
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.425227299835528 at [8, 0]
# Doing "measurement"...
#
# Exploration step 35/100
# # of inducing points for GP regression: 281
# Model training...
# average time per iteration: 0.0215 s
# training completed in 10.28 s
# Final parameter values:
#  amp: 0.0113, lengthscale: [ 7.3006  9.924  18.5976], noise: 0.000578
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7210632057082527 at [9, 31]
# Doing "measurement"...
#
# Exploration step 36/100
# # of inducing points for GP regression: 286
# Model training...
# average time per iteration: 0.0216 s
# training completed in 10.35 s
# Final parameter values:
#  amp: 0.0113, lengthscale: [ 6.7794 10.3667 18.6516], noise: 0.000574
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7671063875626336 at [15, 0]
# Doing "measurement"...
#
# Exploration step 37/100
# # of inducing points for GP regression: 291
# Model training...
# average time per iteration: 0.0222 s
# training completed in 10.78 s
# Final parameter values:
#  amp: 0.0109, lengthscale: [ 6.3374 10.0304 18.8045], noise: 0.0005888
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.865318132337428 at [27, 31]
# Doing "measurement"...
#
# Exploration step 38/100
# # of inducing points for GP regression: 296
# Model training...
# average time per iteration: 0.0232 s
# training completed in 10.68 s
# Final parameter values:
#  amp: 0.0115, lengthscale: [ 6.4237 10.3122 18.809 ], noise: 0.0005779
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7840205216699747 at [21, 31]
# Doing "measurement"...
#
# Exploration step 39/100
# # of inducing points for GP regression: 301
# Model training...
# average time per iteration: 0.0229 s
# training completed in 10.86 s
# Final parameter values:
#  amp: 0.0114, lengthscale: [ 6.2467 10.3614 18.8827], noise: 0.0005808
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8425561638400954 at [21, 0]
# Doing "measurement"...
#
# Exploration step 40/100
# # of inducing points for GP regression: 306
# Model training...
# average time per iteration: 0.0232 s
# training completed in 10.79 s
# Final parameter values:
#  amp: 0.0115, lengthscale: [ 6.1451 10.5723 18.8771], noise: 0.0005736
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8454615181154153 at [27, 0]
# Doing "measurement"...
#
# Exploration step 41/100
# # of inducing points for GP regression: 312
# Model training...
# average time per iteration: 0.0231 s
# training completed in 10.96 s
# Final parameter values:
#  amp: 0.0112, lengthscale: [ 6.1102 10.475  18.6628], noise: 0.000555
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.639481185695556 at [13, 11]
# Doing "measurement"...
#
# Exploration step 42/100
# # of inducing points for GP regression: 317
# Model training...
# average time per iteration: 0.0239 s
# training completed in 11.17 s
# Final parameter values:
#  amp: 0.0111, lengthscale: [ 6.1452 10.5234 18.6638], noise: 0.0005385
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.5938426911323904 at [9, 16]
# Doing "measurement"...
#
# Exploration step 43/100
# # of inducing points for GP regression: 322
# Model training...
# average time per iteration: 0.0242 s
# training completed in 11.5 s
# Final parameter values:
#  amp: 0.0105, lengthscale: [ 6.0977 10.2203 18.406 ], noise: 0.0005408
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6020248464427502 at [18, 25]
# Doing "measurement"...
#
# Exploration step 44/100
# # of inducing points for GP regression: 327
# Model training...
# average time per iteration: 0.0245 s
# training completed in 11.75 s
# Final parameter values:
#  amp: 0.0104, lengthscale: [ 5.836   9.8627 18.6637], noise: 0.0005597
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7006678360418572 at [7, 9]
# Doing "measurement"...
#
# Exploration step 45/100
# # of inducing points for GP regression: 332
# Model training...
# average time per iteration: 0.024700000000000003 s
# training completed in 11.74 s
# Final parameter values:
#  amp: 0.0103, lengthscale: [ 5.7527  9.6605 18.4097], noise: 0.0005807
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.723527679579575 at [8, 26]
# Doing "measurement"...
#
# Exploration step 46/100
# # of inducing points for GP regression: 337
# Model training...
# average time per iteration: 0.0254 s
# training completed in 11.96 s
# Final parameter values:
#  amp: 0.0112, lengthscale: [ 5.9119  9.8936 18.6104], noise: 0.0005705
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.716230112125827 at [19, 15]
# Doing "measurement"...
#
# Exploration step 47/100
# # of inducing points for GP regression: 342
# Model training...
# average time per iteration: 0.025099999999999997 s
# training completed in 12.1 s
# Final parameter values:
#  amp: 0.0103, lengthscale: [ 5.7437  9.5322 18.4729], noise: 0.000565
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.671095987827302 at [23, 12]
# Doing "measurement"...
#
# Exploration step 48/100
# # of inducing points for GP regression: 347
# Model training...
# average time per iteration: 0.0259 s
# training completed in 12.1 s
# Final parameter values:
#  amp: 0.0099, lengthscale: [ 5.7408  9.0169 18.2707], noise: 0.0005671
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6983118100290855 at [3, 27]
# Doing "measurement"...
#
# Exploration step 49/100
# # of inducing points for GP regression: 352
# Model training...
# average time per iteration: 0.026099999999999998 s
# training completed in 12.41 s
# Final parameter values:
#  amp: 0.01, lengthscale: [ 5.7257  9.1669 18.3072], noise: 0.0005677
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.687669456190899 at [28, 16]
# Doing "measurement"...
#
# Exploration step 50/100
# # of inducing points for GP regression: 357
# Model training...
# average time per iteration: 0.026699999999999998 s
# training completed in 12.36 s
# Final parameter values:
#  amp: 0.0102, lengthscale: [ 5.6788  9.2572 18.3441], noise: 0.0005614
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.655520830379992 at [12, 23]
# Doing "measurement"...
#
# Exploration step 51/100
# # of inducing points for GP regression: 363
# Model training...
# average time per iteration: 0.026699999999999998 s
# training completed in 13.19 s
# Final parameter values:
#  amp: 0.0106, lengthscale: [ 5.6246  9.4274 18.4538], noise: 0.0005522
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.675709024970257 at [2, 6]
# Doing "measurement"...
#
# Exploration step 52/100
# # of inducing points for GP regression: 368
# Model training...
# average time per iteration: 0.0276 s
# training completed in 13.17 s
# Final parameter values:
#  amp: 0.0097, lengthscale: [ 5.6011  8.7987 18.1204], noise: 0.0005565
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6678309974123793 at [8, 4]
# Doing "measurement"...
#
# Exploration step 53/100
# # of inducing points for GP regression: 373
# Model training...
# average time per iteration: 0.028900000000000002 s
# training completed in 13.56 s
# Final parameter values:
#  amp: 0.0105, lengthscale: [ 5.7179  9.0956 18.3635], noise: 0.0005431
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.616266231224785 at [28, 7]
# Doing "measurement"...
#
# Exploration step 54/100
# # of inducing points for GP regression: 378
# Model training...
# average time per iteration: 0.0298 s
# training completed in 14.01 s
# Final parameter values:
#  amp: 0.0101, lengthscale: [ 5.6724  8.8557 18.2944], noise: 0.0005472
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.602817561317194 at [18, 6]
# Doing "measurement"...
#
# Exploration step 55/100
# # of inducing points for GP regression: 383
# Model training...
# average time per iteration: 0.029300000000000003 s
# training completed in 13.81 s
# Final parameter values:
#  amp: 0.0101, lengthscale: [ 5.5915  8.9189 18.2739], noise: 0.0005354
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.735372434057647 at [23, 5]
# Doing "measurement"...
#
# Exploration step 56/100
# # of inducing points for GP regression: 388
# Model training...
# average time per iteration: 0.029900000000000003 s
# training completed in 14.08 s
# Final parameter values:
#  amp: 0.0105, lengthscale: [ 5.4655  9.2445 18.4846], noise: 0.0005302
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.5994262517483397 at [2, 16]
# Doing "measurement"...
#
# Exploration step 57/100
# # of inducing points for GP regression: 393
# Model training...
# average time per iteration: 0.0302 s
# training completed in 14.27 s
# Final parameter values:
#  amp: 0.0109, lengthscale: [ 5.5847  9.2697 18.6242], noise: 0.0005293
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.565826644350419 at [24, 20]
# Doing "measurement"...
#
# Exploration step 58/100
# # of inducing points for GP regression: 398
# Model training...
# average time per iteration: 0.0305 s
# training completed in 14.41 s
# Final parameter values:
#  amp: 0.0107, lengthscale: [ 5.5573  9.1712 18.5248], noise: 0.0005189
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.500641253691265 at [23, 26]
# Doing "measurement"...
#
# Exploration step 59/100
# # of inducing points for GP regression: 403
# Model training...
# average time per iteration: 0.031 s
# training completed in 14.99 s
# Final parameter values:
#  amp: 0.01, lengthscale: [ 5.2307  9.0395 18.2461], noise: 0.0005371
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.5902113485540235 at [19, 21]
# Doing "measurement"...
#
# Exploration step 60/100
# # of inducing points for GP regression: 408
# Model training...
# average time per iteration: 0.0308 s
# training completed in 14.57 s
# Final parameter values:
#  amp: 0.0102, lengthscale: [ 5.2298  9.0522 18.2511], noise: 0.0005402
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.53640111456231 at [7, 21]
# Doing "measurement"...
#
# Exploration step 61/100
# # of inducing points for GP regression: 414
# Model training...
# average time per iteration: 0.0313 s
# training completed in 15.07 s
# Final parameter values:
#  amp: 0.0091, lengthscale: [ 4.8697  8.6594 17.6797], noise: 0.0005658
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.631614762399213 at [29, 23]
# Doing "measurement"...
#
# Exploration step 62/100
# # of inducing points for GP regression: 419
# Model training...
# average time per iteration: 0.0322 s
# training completed in 15.27 s
# Final parameter values:
#  amp: 0.0097, lengthscale: [ 4.9635  8.8724 17.827 ], noise: 0.0005527
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.4861193958156527 at [7, 12]
# Doing "measurement"...
#
# Exploration step 63/100
# # of inducing points for GP regression: 424
# Model training...
# average time per iteration: 0.0321 s
# training completed in 15.5 s
# Final parameter values:
#  amp: 0.0082, lengthscale: [ 5.1632  6.9124 17.1813], noise: 0.0005953
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.817872533455483 at [3, 9]
# Doing "measurement"...
#
# Exploration step 64/100
# # of inducing points for GP regression: 429
# Model training...
# average time per iteration: 0.0327 s
# training completed in 15.78 s
# Final parameter values:
#  amp: 0.0079, lengthscale: [ 5.0462  6.21   17.1952], noise: 0.0006297
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 4.082590763014112 at [0, 21]
# Doing "measurement"...
#
# Exploration step 65/100
# # of inducing points for GP regression: 434
# Model training...
# average time per iteration: 0.0333 s
# training completed in 15.76 s
# Final parameter values:
#  amp: 0.0083, lengthscale: [ 5.0401  6.5569 17.2671], noise: 0.0006118
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8897569334525706 at [28, 28]
# Doing "measurement"...
#
# Exploration step 66/100
# # of inducing points for GP regression: 439
# Model training...
# average time per iteration: 0.0333 s
# training completed in 16.07 s
# Final parameter values:
#  amp: 0.0084, lengthscale: [ 4.9963  6.674  17.3557], noise: 0.0006007
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.824106538121073 at [3, 22]
# Doing "measurement"...
#
# Exploration step 67/100
# # of inducing points for GP regression: 444
# Model training...
# average time per iteration: 0.0345 s
# training completed in 16.03 s
# Final parameter values:
#  amp: 0.0088, lengthscale: [ 5.071   6.8612 17.4884], noise: 0.0005824
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7523091122915515 at [14, 28]
# Doing "measurement"...
#
# Exploration step 68/100
# # of inducing points for GP regression: 449
# Model training...
# average time per iteration: 0.0366 s
# training completed in 16.82 s
# Final parameter values:
#  amp: 0.0081, lengthscale: [ 4.8484  6.5244 17.0795], noise: 0.000609
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8855454906087705 at [12, 8]
# Doing "measurement"...
#
# Exploration step 69/100
# # of inducing points for GP regression: 454
# Model training...
# average time per iteration: 0.0354 s
# training completed in 16.94 s
# Final parameter values:
#  amp: 0.0084, lengthscale: [ 4.8803  6.649  17.1566], noise: 0.0006143
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8501260485173243 at [14, 3]
# Doing "measurement"...
#
# Exploration step 70/100
# # of inducing points for GP regression: 459
# Model training...
# average time per iteration: 0.0353 s
# training completed in 16.9 s
# Final parameter values:
#  amp: 0.0083, lengthscale: [ 4.913   6.4563 17.1623], noise: 0.0006064
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8921231390965474 at [15, 21]
# Doing "measurement"...
#
# Exploration step 71/100
# # of inducing points for GP regression: 465
# Model training...
# average time per iteration: 0.0363 s
# training completed in 17.51 s
# Final parameter values:
#  amp: 0.0082, lengthscale: [ 4.8616  6.5461 17.045 ], noise: 0.0005906
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7555128160256377 at [24, 9]
# Doing "measurement"...
#
# Exploration step 72/100
# # of inducing points for GP regression: 470
# Model training...
# average time per iteration: 0.0366 s
# training completed in 17.64 s
# Final parameter values:
#  amp: 0.0084, lengthscale: [ 4.9345  6.5914 17.1103], noise: 0.0005826
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.715514960915451 at [0, 3]
# Doing "measurement"...
#
# Exploration step 73/100
# # of inducing points for GP regression: 475
# Model training...
# average time per iteration: 0.0388 s
# training completed in 17.99 s
# Final parameter values:
#  amp: 0.0087, lengthscale: [ 4.8809  6.807  17.3406], noise: 0.0005741
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.671451809618922 at [0, 9]
# Doing "measurement"...
#
# Exploration step 74/100
# # of inducing points for GP regression: 480
# Model training...
# average time per iteration: 0.0379 s
# training completed in 18.18 s
# Final parameter values:
#  amp: 0.0091, lengthscale: [ 4.9936  6.8916 17.4026], noise: 0.0005564
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.5764656737984852 at [31, 3]
# Doing "measurement"...
#
# Exploration step 75/100
# # of inducing points for GP regression: 485
# Model training...
# average time per iteration: 0.0373 s
# training completed in 18.06 s
# Final parameter values:
#  amp: 0.0084, lengthscale: [ 4.9364  6.4422 17.1478], noise: 0.000571
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6702687163356225 at [28, 13]
# Doing "measurement"...
#
# Exploration step 76/100
# # of inducing points for GP regression: 490
# Model training...
# average time per iteration: 0.0384 s
# training completed in 18.46 s
# Final parameter values:
#  amp: 0.0086, lengthscale: [ 5.0257  6.0598 17.3383], noise: 0.0005837
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8340279909464714 at [31, 15]
# Doing "measurement"...
#
# Exploration step 77/100
# # of inducing points for GP regression: 495
# Model training...
# average time per iteration: 0.04019999999999999 s
# training completed in 19.05 s
# Final parameter values:
#  amp: 0.0087, lengthscale: [ 5.1287  5.9422 17.4221], noise: 0.0005799
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.9629105621361975 at [31, 21]
# Doing "measurement"...
#
# Exploration step 78/100
# # of inducing points for GP regression: 500
# Model training...
# average time per iteration: 0.0384 s
# training completed in 18.68 s
# Final parameter values:
#  amp: 0.0089, lengthscale: [ 5.1176  6.0601 17.5064], noise: 0.0005664
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8116548714446554 at [31, 9]
# Doing "measurement"...
#
# Exploration step 79/100
# # of inducing points for GP regression: 505
# Model training...
# average time per iteration: 0.0392 s
# training completed in 18.97 s
# Final parameter values:
#  amp: 0.0089, lengthscale: [ 5.1105  6.0338 17.5643], noise: 0.000564
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7597051133159174 at [0, 15]
# Doing "measurement"...
#
# Exploration step 80/100
# # of inducing points for GP regression: 510
# Model training...
# average time per iteration: 0.0397 s
# training completed in 19.0 s
# Final parameter values:
#  amp: 0.0084, lengthscale: [ 5.1039  5.7527 17.2806], noise: 0.0005658
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7634333027387075 at [17, 3]
# Doing "measurement"...
#
# Exploration step 81/100
# # of inducing points for GP regression: 516
# Model training...
# average time per iteration: 0.0426 s
# training completed in 20.58 s
# Final parameter values:
#  amp: 0.0085, lengthscale: [ 5.1576  5.7826 17.2623], noise: 0.0005613
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.781566569670568 at [19, 9]
# Doing "measurement"...
#
# Exploration step 82/100
# # of inducing points for GP regression: 521
# Model training...
# average time per iteration: 0.0437 s
# training completed in 20.95 s
# Final parameter values:
#  amp: 0.0085, lengthscale: [ 5.1086  5.7609 17.3581], noise: 0.0005507
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.680381868548388 at [16, 8]
# Doing "measurement"...
#
# Exploration step 83/100
# # of inducing points for GP regression: 526
# Model training...
# average time per iteration: 0.043899999999999995 s
# training completed in 21.31 s
# Final parameter values:
#  amp: 0.0086, lengthscale: [ 5.1596  5.7942 17.2674], noise: 0.0005412
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.657076726513395 at [0, 28]
# Doing "measurement"...
#
# Exploration step 84/100
# # of inducing points for GP regression: 531
# Model training...
# average time per iteration: 0.0458 s
# training completed in 22.14 s
# Final parameter values:
#  amp: 0.0091, lengthscale: [ 5.2754  5.8304 17.5578], noise: 0.0005437
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6934667747548895 at [6, 29]
# Doing "measurement"...
#
# Exploration step 85/100
# # of inducing points for GP regression: 536
# Model training...
# average time per iteration: 0.044000000000000004 s
# training completed in 21.4 s
# Final parameter values:
#  amp: 0.0089, lengthscale: [ 5.2658  5.7217 17.5119], noise: 0.0005372
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.682293341876602 at [0, 31]
# Doing "measurement"...
#
# Exploration step 86/100
# # of inducing points for GP regression: 541
# Model training...
# average time per iteration: 0.047 s
# training completed in 22.55 s
# Final parameter values:
#  amp: 0.0098, lengthscale: [ 5.3851  5.6766 17.9254], noise: 0.0005751
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.793832389409638 at [21, 3]
# Doing "measurement"...
#
# Exploration step 87/100
# # of inducing points for GP regression: 546
# Model training...
# average time per iteration: 0.046900000000000004 s
# training completed in 22.83 s
# Final parameter values:
#  amp: 0.0098, lengthscale: [ 5.393   5.6833 17.8588], noise: 0.0005785
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8066372833704545 at [20, 13]
# Doing "measurement"...
#
# Exploration step 88/100
# # of inducing points for GP regression: 551
# Model training...
# average time per iteration: 0.0484 s
# training completed in 22.95 s
# Final parameter values:
#  amp: 0.0096, lengthscale: [ 5.3338  5.6328 17.8539], noise: 0.0005679
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.8138975191895743 at [15, 13]
# Doing "measurement"...
#
# Exploration step 89/100
# # of inducing points for GP regression: 556
# Model training...
# average time per iteration: 0.0475 s
# training completed in 23.26 s
# Final parameter values:
#  amp: 0.0103, lengthscale: [ 5.6168  5.5815 18.0721], noise: 0.0005542
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7630152699273918 at [17, 28]
# Doing "measurement"...
#
# Exploration step 90/100
# # of inducing points for GP regression: 561
# Model training...
# average time per iteration: 0.0471 s
# training completed in 23.01 s
# Final parameter values:
#  amp: 0.0096, lengthscale: [ 5.0397  5.7598 17.9519], noise: 0.0005743
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7878159342943114 at [25, 23]
# Doing "measurement"...
#
# Exploration step 91/100
# # of inducing points for GP regression: 567
# Model training...
# average time per iteration: 0.0496 s
# training completed in 23.85 s
# Final parameter values:
#  amp: 0.0093, lengthscale: [ 4.966   5.696  17.7637], noise: 0.0005765
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.7738607980270014 at [12, 16]
# Doing "measurement"...
#
# Exploration step 92/100
# # of inducing points for GP regression: 572
# Model training...
# average time per iteration: 0.049100000000000005 s
# training completed in 24.04 s
# Final parameter values:
#  amp: 0.0097, lengthscale: [ 5.0118  5.8137 17.8559], noise: 0.0005713
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.749808843625659 at [23, 18]
# Doing "measurement"...
#
# Exploration step 93/100
# # of inducing points for GP regression: 577
# Model training...
# average time per iteration: 0.0508 s
# training completed in 24.75 s
# Final parameter values:
#  amp: 0.0097, lengthscale: [ 4.8686  5.8539 17.8314], noise: 0.000577
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.805818843969324 at [17, 17]
# Doing "measurement"...
#
# Exploration step 94/100
# # of inducing points for GP regression: 582
# Model training...
# average time per iteration: 0.0536 s
# training completed in 25.45 s
# Final parameter values:
#  amp: 0.0097, lengthscale: [ 4.8537  5.9009 17.8104], noise: 0.0005689
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.6981321928567557 at [9, 19]
# Doing "measurement"...
#
# Exploration step 95/100
# # of inducing points for GP regression: 587
# Model training...
# average time per iteration: 0.051 s
# training completed in 25.18 s
# Final parameter values:
#  amp: 0.0095, lengthscale: [ 4.7673  5.9184 17.7997], noise: 0.0005711
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.759279876837859 at [3, 17]
# Doing "measurement"...
#
# Exploration step 96/100
# # of inducing points for GP regression: 592
# Model training...
# average time per iteration: 0.052000000000000005 s
# training completed in 25.42 s
# Final parameter values:
#  amp: 0.0094, lengthscale: [ 4.8179  5.7787 17.8136], noise: 0.000567
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.689466676244953 at [3, 3]
# Doing "measurement"...
#
# Exploration step 97/100
# # of inducing points for GP regression: 597
# Model training...
# average time per iteration: 0.0542 s
# training completed in 26.37 s
# Final parameter values:
#  amp: 0.0096, lengthscale: [ 4.8801  5.7769 17.8162], noise: 0.0005596
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.722958729804809 at [10, 2]
# Doing "measurement"...
#
# Exploration step 98/100
# # of inducing points for GP regression: 602
# Model training...
# average time per iteration: 0.0556 s
# training completed in 26.55 s
# Final parameter values:
#  amp: 0.0094, lengthscale: [ 4.7757  5.7023 17.7297], noise: 0.0005693
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.703687698457193 at [22, 7]
# Doing "measurement"...
#
# Exploration step 99/100
# # of inducing points for GP regression: 607
# Model training...
# average time per iteration: 0.056600000000000004 s
# training completed in 27.21 s
# Final parameter values:
#  amp: 0.0094, lengthscale: [ 4.7416  5.7372 17.7026], noise: 0.0005652
# Calculating predictive mean and variance... Done
# Maximum uncertainty of 3.698278673010682 at [23, 29]
# Doing "measurement"...

# %% [markdown]
# Plot the results:

# %%
steps = [10, 20, 30, 99] # view results at these exploration steps
pos = [
       [10, 20], 
       [24, 22], 
       [24, 10],
]
slice_number = 57
spec_window = 10
dist_edge = DIST_EDGE

gprutils.plot_exploration_results(
    R_all, mean_all, sd_all, R_true, steps,
    slice_number, pos, dist_edge, spec_window)

# %% [markdown]
# Plot the exploration path in the *xy* space:

# %%
n_points = 60
colormap = cm.cool
gp_points = np.array(uncert_idx_all)
colorst = [colormap(i) for i in np.linspace(0, 0.9, n_points)]
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.set_xlim(-1, 33)
ax.set_ylim(-1, 33)
for j in range(n_points-1):
    x, y = gp_points[j] 
    dx = gp_points[j+1][0] - x
    dy = gp_points[j+1][1] - y
    ax.arrow(y, x, dy, dx, length_includes_head=True, head_width=0.4, color=colorst[j])
plt.scatter(gp_points[:n_points, 1], gp_points[:n_points, 0])
clrbar = np.linspace(0, n_points-1).reshape(-1, 1)
ax2 = fig.add_axes([.78, .1, .2, .8])
img = plt.imshow(clrbar, colormap)
plt.gca().set_visible(False)
clrbar_ = plt.colorbar(img, ax=ax2, orientation='vertical')
clrbar_.set_label('Exploration steps', fontsize=14, labelpad=10)
plt.show()

# %% [markdown]
# We can also quickly calculate and plot integrated absolute error versus exploration steps:

# %%
e1, e2, e3 = R_true.shape
R_true_masked = gprutils.mask_edges(np.sum(R_true, -1), DIST_EDGE)
sum_error_gp, sum_error_stand = [], []
for i in range(EXPLORATION_STEPS):
    mean_i = gprutils.mask_edges(
        np.sum(mean_all[i].reshape(e1, e2, e3), -1), DIST_EDGE)
    sum_error = np.sum(np.abs(R_true_masked - mean_i))
    partial_img = gprutils.mask_edges(
        np.sum(np.nan_to_num(R_all[i]).reshape(e1, e2, e3), -1), DIST_EDGE)
    sum_error_ = np.sum(np.abs(R_true_masked - partial_img))
    sum_error_gp.append(sum_error)
    sum_error_stand.append(sum_error_)
# plot results
plt.figure(figsize=(8, 6))
plt.plot(sum_error_gp, '-o', label='GP')
plt.plot(sum_error_stand, '-o', label='Standard')
plt.xlabel('Exploration step', fontsize=18)
plt.ylabel('Integrated error (arb. units)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.show()
